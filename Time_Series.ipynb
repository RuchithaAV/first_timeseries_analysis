# %% [markdown]
# <a href="https://colab.research.google.com/github/RuchithaAV/first_timeseries_analysis/blob/main/Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/AAPL.csv', parse_dates=["Date"], index_col="Date")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4670/2974816431.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/AAPL.csv', parse_dates=["Date"], index_col="Date")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4670/964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.index

# %%
df.info()

# %%
type(df.index)

# %%
df['1980-12']

# %%
df.describe()

# %%
df

# %%
df.loc['2022']

# %%
df.loc['2022-03'].Close.mean()

# %%
df['2022-01-01':'2022-02-01'].Low.mean()

# %%
df.Close.resample('M').mean()

# %%
df.Close.resample('Y').mean().plot()

# %%
df.Close.resample('M').mean().plot()

# %%
df.Close.resample('D').mean().plot()

# %%
df.Close.resample('B').mean().plot()

# %%
df.Close.resample('Y').mean().plot(kind='bar')

# %%
df.Close.resample('Y').mean().plot(kind='barh')

# %%
df.Low.resample('M').max().plot()

# %%
rng = pd.date_range(start='1980-12-12', end='2022-03-24', freq='B')
rng

# %%
df.set_index(rng, inplace = True)

# %%
new_rng = pd.date_range(start='2019-01-01', periods=len(df), freq='B')
print(f"Length of new date range: {len(new_rng)}")
print(f"Length of DataFrame df: {len(df)}")
display(new_rng)

# %%
df

# %%
df['2017-01-01':'2017-12-31'].Close.mean().plot()

# %%
df.asfreq("D", method="pad")

# %%
df.asfreq("H", method='pad').plot()
